# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib notebook
# Commands for continuous package development

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# %%
viridis = cm.get_cmap('viridis', 256)
oldcolors = viridis(np.linspace(0, 1, 256))
newcolors = np.array([[(1-col[0]), (1-col[1]), (1-col[2]), 1] for col in oldcolors])
newcmp = ListedColormap(newcolors)

# %%
from tephra2utils import io, vis

# %%
df, _, _, _ = io.read_tephra2("gsm_out_test.txt")

# %%
ax = vis.plot_contour(df, cbar_label="Mass/Area", vent=(0,0),
                      cmap='magma', 
                      background='gradient',
                     line_cmap='negative', log=True)
fig = plt.gcf()

plt.tight_layout()
plt.show()
# Out:
# c:\users\nmostert\envs\spew\lib\site-packages\numpy\core\_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# c:\users\nmostert\envs\spew\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# <img src="data:image/png;base64,..." width="638.888905813665">
# c:\users\nmostert\envs\spew\lib\site-packages\matplotlib\colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
r, g, b = [j for j in range(3)]

# %%
b
# Out:
# 2
